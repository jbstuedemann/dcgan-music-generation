# %%
from scipy.io import wavfile
from scipy.fft import fft, fftfreq
import numpy as np
import matplotlib.pyplot as plt
import math
import datetime
import os
import threading

# %%
def save_fft_data(song_name, frame_length=10, n_threads=8):

    filepath = f"./songs/{song_name}.wav"

    # load wav
    print(f"Loading {filepath}")
    samplerate, data = wavfile.read(filepath)
    bin_step = math.floor(samplerate / 100)

    # make dir
    if (not os.path.isdir("./data")):
        print("Creating directory ./data/")
        os.mkdir("./data/")
    if (not os.path.isdir("./data/fft")):
        print("Creating directory ./data/fft/")
        os.mkdir("./data/fft/")
    if (not os.path.isdir(f"./data/fft/{song_name}/")):
        print(f"Creating directory ./data/fft/{song_name}/")
        os.mkdir(f"./data/fft/{song_name}/")
    
    print(f"Saving data to ./{song_name}/")

    # save one frame of data
    def save_frame(start_bin, thread_i):
        fft_bins = []
        end_bin = start_bin+math.floor(samplerate/bin_step*frame_length)
        for i_bin in range(start_bin, end_bin):
            sample_start = i_bin*bin_step
            sample_end = sample_start + samplerate
            bin = data[sample_start:sample_end,:]

            # take ffts
            channel_0_fft = np.abs(fft(bin[:,0])[1:samplerate//2])
            channel_1_fft = np.abs(fft(bin[:,1])[1:samplerate//2])

            fft_bins.append(np.mean(np.array([channel_0_fft, channel_1_fft]), axis=0))

        print(f"| thread_{thread_i}:\ttime processed: {datetime.timedelta(seconds=(end_bin*bin_step)/samplerate)}")
        np.save(f"./data/fft/{song_name}/{start_bin*bin_step}-{end_bin*bin_step}.npy", np.clip(np.log(np.array(fft_bins))/20, 0, 1))

    # multithreading function
    def thread_task_frame(bins, thread_i):
        for bin in bins:
            save_frame(bin, thread_i)
        print(f"thread_{thread_i} finished.")

    threads = []
    n_bins = math.ceil((data.shape[0]-samplerate)/bin_step)
    thread_bins = [[] for _ in range(n_threads)]
    for i in range(n_bins//math.floor(samplerate/bin_step*frame_length)):
        thread_bins[i%n_threads] += [i*math.floor(samplerate/bin_step*frame_length)]

    for bins in thread_bins:
        thread_index = len(threads)
        print(f"Tasking thread_{thread_index} to {bins}")
        threads.append(threading.Thread(target=thread_task_frame, args=(bins, thread_index)))
        threads[thread_index].start()

    for i in range(n_threads):
        threads[i].join()
        print(f"Joining thread_{i}")

    return 0

# %%
def sort_key(element):
    try:
        return int(element.split("-")[0])
    except:
        return -1

def combine_files(directory):
    full_frames = []
    files = os.listdir(f"./data/fft/{directory}/")
    files.sort(key=sort_key)
    for filename in files:
        filepath = f"./data/fft/{directory}/{filename}"
        if not os.path.isfile(filepath) or not filename[-3:]=='npy': continue
        data = np.load(filepath)
        full_frames += [data]
    np.save(f"{directory}.npy", np.array(full_frames).reshape(-1, 23999))

# %%
save_fft_data("test_song", frame_length=10, n_threads=8)
# Out:
# Loading ./songs/test_song.wav
# Creating directory ./data/
# Creating directory ./data/fft/
# Creating directory ./data/fft/test_song/
# Saving data to ./test_song/
# Tasking thread_0 to [0, 8000, 16000]
# Tasking thread_1 to [1000, 9000, 17000]
# Tasking thread_2 to [2000, 10000, 18000]
# Tasking thread_3 to [3000, 11000, 19000]
# Tasking thread_4 to [4000, 12000, 20000]
# Tasking thread_5 to [5000, 13000]
# Tasking thread_6 to [6000, 14000]
# Tasking thread_7 to [7000, 15000]
# | thread_5:	time processed: 0:01:00
# | thread_4:	time processed: 0:00:50
# | thread_1:	time processed: 0:00:20
# | thread_3:	time processed: 0:00:40
# | thread_2:	time processed: 0:00:30
# | thread_6:	time processed: 0:01:10
# | thread_0:	time processed: 0:00:10
# | thread_7:	time processed: 0:01:20
# | thread_5:	time processed: 0:02:20
# | thread_4:	time processed: 0:02:10
# | thread_3:	time processed: 0:02:00
# | thread_1:	time processed: 0:01:40
# | thread_0:	time processed: 0:01:30
# | thread_7:	time processed: 0:02:40
# | thread_6:	time processed: 0:02:30
# | thread_2:	time processed: 0:01:50
# thread_5 finished.
# thread_7 finished.
# thread_6 finished.
# | thread_4:	time processed: 0:03:30
# | thread_3:	time processed: 0:03:20
# | thread_2:	time processed: 0:03:10
# | thread_1:	time processed: 0:03:00
# | thread_0:	time processed: 0:02:50
# thread_4 finished.
# thread_3 finished.
# thread_2 finished.
# thread_0 finished.thread_1 finished.
# Joining thread_0
#
# Joining thread_1
# Joining thread_2
# Joining thread_3
# Joining thread_4
# Joining thread_5
# Joining thread_6
# Joining thread_7
# 0

# %%
combine_files("test_song")
plt.imsave("test_song.png", np.load("test_song.npy").transpose())

# %%
save_fft_data("classical", frame_length=10, n_threads=8)
# Out:
# Loading ./songs/classical.wav
# Creating directory ./data/fft/classical/
# Saving data to ./classical/
# Tasking thread_0 to [0, 8000, 16000, 24000, 32000, 40000, 48000, 56000, 64000, 72000, 80000, 88000, 96000, 104000, 112000, 120000, 128000, 136000, 144000, 152000, 160000, 168000, 176000, 184000, 192000, 200000, 208000, 216000, 224000, 232000, 240000, 248000, 256000, 264000, 272000, 280000, 288000, 296000, 304000, 312000, 320000, 328000, 336000, 344000, 352000, 360000, 368000, 376000, 384000, 392000, 400000, 408000, 416000, 424000, 432000, 440000, 448000, 456000, 464000, 472000, 480000, 488000, 496000, 504000, 512000, 520000, 528000, 536000, 544000, 552000, 560000, 568000, 576000, 584000, 592000, 600000, 608000, 616000, 624000, 632000, 640000, 648000, 656000, 664000, 672000, 680000, 688000, 696000, 704000, 712000, 720000, 728000, 736000, 744000, 752000, 760000, 768000, 776000, 784000, 792000, 800000, 808000, 816000, 824000, 832000, 840000, 848000, 856000, 864000, 872000, 880000, 888000, 896000, 904000]
# Tasking thread_1 to [1000, 9000, 17000, 25000, 33000, 41000, 49000, 57000, 65000, 73000, 81000, 89000, 97000, 105000, 113000, 121000, 129000, 137000, 145000, 153000, 161000, 169000, 177000, 185000, 193000, 201000, 209000, 217000, 225000, 233000, 241000, 249000, 257000, 265000, 273000, 281000, 289000, 297000, 305000, 313000, 321000, 329000, 337000, 345000, 353000, 361000, 369000, 377000, 385000, 393000, 401000, 409000, 417000, 425000, 433000, 441000, 449000, 457000, 465000, 473000, 481000, 489000, 497000, 505000, 513000, 521000, 529000, 537000, 545000, 553000, 561000, 569000, 577000, 585000, 593000, 601000, 609000, 617000, 625000, 633000, 641000, 649000, 657000, 665000, 673000, 681000, 689000, 697000, 705000, 713000, 721000, 729000, 737000, 745000, 753000, 761000, 769000, 777000, 785000, 793000, 801000, 809000, 817000, 825000, 833000, 841000, 849000, 857000, 865000, 873000, 881000, 889000, 897000, 905000]
# Tasking thread_2 to [2000, 10000, 18000, 26000, 34000, 42000, 50000, 58000, 66000, 74000, 82000, 90000, 98000, 106000, 114000, 122000, 130000, 138000, 146000, 154000, 162000, 170000, 178000, 186000, 194000, 202000, 210000, 218000, 226000, 234000, 242000, 250000, 258000, 266000, 274000, 282000, 290000, 298000, 306000, 314000, 322000, 330000, 338000, 346000, 354000, 362000, 370000, 378000, 386000, 394000, 402000, 410000, 418000, 426000, 434000, 442000, 450000, 458000, 466000, 474000, 482000, 490000, 498000, 506000, 514000, 522000, 530000, 538000, 546000, 554000, 562000, 570000, 578000, 586000, 594000, 602000, 610000, 618000, 626000, 634000, 642000, 650000, 658000, 666000, 674000, 682000, 690000, 698000, 706000, 714000, 722000, 730000, 738000, 746000, 754000, 762000, 770000, 778000, 786000, 794000, 802000, 810000, 818000, 826000, 834000, 842000, 850000, 858000, 866000, 874000, 882000, 890000, 898000, 906000]
# Tasking thread_3 to [3000, 11000, 19000, 27000, 35000, 43000, 51000, 59000, 67000, 75000, 83000, 91000, 99000, 107000, 115000, 123000, 131000, 139000, 147000, 155000, 163000, 171000, 179000, 187000, 195000, 203000, 211000, 219000, 227000, 235000, 243000, 251000, 259000, 267000, 275000, 283000, 291000, 299000, 307000, 315000, 323000, 331000, 339000, 347000, 355000, 363000, 371000, 379000, 387000, 395000, 403000, 411000, 419000, 427000, 435000, 443000, 451000, 459000, 467000, 475000, 483000, 491000, 499000, 507000, 515000, 523000, 531000, 539000, 547000, 555000, 563000, 571000, 579000, 587000, 595000, 603000, 611000, 619000, 627000, 635000, 643000, 651000, 659000, 667000, 675000, 683000, 691000, 699000, 707000, 715000, 723000, 731000, 739000, 747000, 755000, 763000, 771000, 779000, 787000, 795000, 803000, 811000, 819000, 827000, 835000, 843000, 851000, 859000, 867000, 875000, 883000, 891000, 899000, 907000]
# Tasking thread_4 to [4000, 12000, 20000, 28000, 36000, 44000, 52000, 60000, 68000, 76000, 84000, 92000, 100000, 108000, 116000, 124000, 132000, 140000, 148000, 156000, 164000, 172000, 180000, 188000, 196000, 204000, 212000, 220000, 228000, 236000, 244000, 252000, 260000, 268000, 276000, 284000, 292000, 300000, 308000, 316000, 324000, 332000, 340000, 348000, 356000, 364000, 372000, 380000, 388000, 396000, 404000, 412000, 420000, 428000, 436000, 444000, 452000, 460000, 468000, 476000, 484000, 492000, 500000, 508000, 516000, 524000, 532000, 540000, 548000, 556000, 564000, 572000, 580000, 588000, 596000, 604000, 612000, 620000, 628000, 636000, 644000, 652000, 660000, 668000, 676000, 684000, 692000, 700000, 708000, 716000, 724000, 732000, 740000, 748000, 756000, 764000, 772000, 780000, 788000, 796000, 804000, 812000, 820000, 828000, 836000, 844000, 852000, 860000, 868000, 876000, 884000, 892000, 900000, 908000]
# Tasking thread_5 to [5000, 13000, 21000, 29000, 37000, 45000, 53000, 61000, 69000, 77000, 85000, 93000, 101000, 109000, 117000, 125000, 133000, 141000, 149000, 157000, 165000, 173000, 181000, 189000, 197000, 205000, 213000, 221000, 229000, 237000, 245000, 253000, 261000, 269000, 277000, 285000, 293000, 301000, 309000, 317000, 325000, 333000, 341000, 349000, 357000, 365000, 373000, 381000, 389000, 397000, 405000, 413000, 421000, 429000, 437000, 445000, 453000, 461000, 469000, 477000, 485000, 493000, 501000, 509000, 517000, 525000, 533000, 541000, 549000, 557000, 565000, 573000, 581000, 589000, 597000, 605000, 613000, 621000, 629000, 637000, 645000, 653000, 661000, 669000, 677000, 685000, 693000, 701000, 709000, 717000, 725000, 733000, 741000, 749000, 757000, 765000, 773000, 781000, 789000, 797000, 805000, 813000, 821000, 829000, 837000, 845000, 853000, 861000, 869000, 877000, 885000, 893000, 901000, 909000]
# Tasking thread_6 to [6000, 14000, 22000, 30000, 38000, 46000, 54000, 62000, 70000, 78000, 86000, 94000, 102000, 110000, 118000, 126000, 134000, 142000, 150000, 158000, 166000, 174000, 182000, 190000, 198000, 206000, 214000, 222000, 230000, 238000, 246000, 254000, 262000, 270000, 278000, 286000, 294000, 302000, 310000, 318000, 326000, 334000, 342000, 350000, 358000, 366000, 374000, 382000, 390000, 398000, 406000, 414000, 422000, 430000, 438000, 446000, 454000, 462000, 470000, 478000, 486000, 494000, 502000, 510000, 518000, 526000, 534000, 542000, 550000, 558000, 566000, 574000, 582000, 590000, 598000, 606000, 614000, 622000, 630000, 638000, 646000, 654000, 662000, 670000, 678000, 686000, 694000, 702000, 710000, 718000, 726000, 734000, 742000, 750000, 758000, 766000, 774000, 782000, 790000, 798000, 806000, 814000, 822000, 830000, 838000, 846000, 854000, 862000, 870000, 878000, 886000, 894000, 902000, 910000]
# Tasking thread_7 to [7000, 15000, 23000, 31000, 39000, 47000, 55000, 63000, 71000, 79000, 87000, 95000, 103000, 111000, 119000, 127000, 135000, 143000, 151000, 159000, 167000, 175000, 183000, 191000, 199000, 207000, 215000, 223000, 231000, 239000, 247000, 255000, 263000, 271000, 279000, 287000, 295000, 303000, 311000, 319000, 327000, 335000, 343000, 351000, 359000, 367000, 375000, 383000, 391000, 399000, 407000, 415000, 423000, 431000, 439000, 447000, 455000, 463000, 471000, 479000, 487000, 495000, 503000, 511000, 519000, 527000, 535000, 543000, 551000, 559000, 567000, 575000, 583000, 591000, 599000, 607000, 615000, 623000, 631000, 639000, 647000, 655000, 663000, 671000, 679000, 687000, 695000, 703000, 711000, 719000, 727000, 735000, 743000, 751000, 759000, 767000, 775000, 783000, 791000, 799000, 807000, 815000, 823000, 831000, 839000, 847000, 855000, 863000, 871000, 879000, 887000, 895000, 903000, 911000]
# | thread_4:	time processed: 0:00:50
# | thread_5:	time processed: 0:01:00
# | thread_3:	time processed: 0:00:40
# | thread_7:	time processed: 0:01:20
# | thread_1:	time processed: 0:00:20
# | thread_2:	time processed: 0:00:30
# | thread_6:	time processed: 0:01:10
# | thread_0:	time processed: 0:00:10
# | thread_4:	time processed: 0:02:10
# | thread_3:	time processed: 0:02:00
# | thread_1:	time processed: 0:01:40
# | thread_2:	time processed: 0:01:50
# | thread_5:	time processed: 0:02:20
# | thread_7:	time processed: 0:02:40
# | thread_6:	time processed: 0:02:30
# | thread_0:	time processed: 0:01:30
# | thread_4:	time processed: 0:03:30
# | thread_3:	time processed: 0:03:20
# | thread_5:	time processed: 0:03:40
# | thread_6:	time processed: 0:03:50
# | thread_7:	time processed: 0:04:00
# | thread_2:	time processed: 0:03:10
# | thread_0:	time processed: 0:02:50
# | thread_1:	time processed: 0:03:00
# | thread_4:	time processed: 0:04:50
# | thread_7:	time processed: 0:05:20
# | thread_6:	time processed: 0:05:10
# | thread_5:	time processed: 0:05:00
# | thread_0:	time processed: 0:04:10
# | thread_3:	time processed: 0:04:40
# | thread_2:	time processed: 0:04:30
# | thread_1:	time processed: 0:04:20
# | thread_4:	time processed: 0:06:10
# | thread_7:	time processed: 0:06:40
# | thread_6:	time processed: 0:06:30
# | thread_5:	time processed: 0:06:20
# | thread_0:	time processed: 0:05:30
# | thread_3:	time processed: 0:06:00
# | thread_1:	time processed: 0:05:40
# | thread_2:	time processed: 0:05:50
# | thread_4:	time processed: 0:07:30
# | thread_7:	time processed: 0:08:00
# | thread_5:	time processed: 0:07:40
# | thread_2:	time processed: 0:07:10
# | thread_6:	time processed: 0:07:50
# | thread_0:	time processed: 0:06:50
# | thread_3:	time processed: 0:07:20
# | thread_1:	time processed: 0:07:00
# | thread_4:	time processed: 0:08:50
# | thread_7:	time processed: 0:09:20
# | thread_5:	time processed: 0:09:00
# | thread_6:	time processed: 0:09:10
# | thread_4:	time processed: 0:10:10
# | thread_3:	time processed: 0:08:40
# | thread_1:	time processed: 0:08:20
# | thread_2:	time processed: 0:08:30
# | thread_0:	time processed: 0:08:10
# | thread_7:	time processed: 0:10:40
# | thread_5:	time processed: 0:10:20
# | thread_4:	time processed: 0:11:30
# | thread_2:	time processed: 0:09:50
# | thread_6:	time processed: 0:10:30
# | thread_3:	time processed: 0:10:00
# | thread_1:	time processed: 0:09:40
# | thread_0:	time processed: 0:09:30
# | thread_7:	time processed: 0:12:00
# | thread_5:	time processed: 0:11:40
# | thread_4:	time processed: 0:12:50
# | thread_2:	time processed: 0:11:10
# | thread_6:	time processed: 0:11:50
# | thread_0:	time processed: 0:10:50
# | thread_1:	time processed: 0:11:00
# | thread_3:	time processed: 0:11:20
# | thread_7:	time processed: 0:13:20
# | thread_5:	time processed: 0:13:00
# | thread_7:	time processed: 0:14:40
# | thread_3:	time processed: 0:12:40
# | thread_6:	time processed: 0:13:10
# | thread_1:	time processed: 0:12:20
# | thread_2:	time processed: 0:12:30
# | thread_0:	time processed: 0:12:10
# | thread_4:	time processed: 0:14:10
# | thread_5:	time processed: 0:14:20
# | thread_3:	time processed: 0:14:00
# | thread_7:	time processed: 0:16:00
# | thread_0:	time processed: 0:13:30
# | thread_6:	time processed: 0:14:30
# | thread_1:	time processed: 0:13:40
# | thread_4:	time processed: 0:15:30
# | thread_2:	time processed: 0:13:50
# | thread_5:	time processed: 0:15:40
# | thread_3:	time processed: 0:15:20
# | thread_7:	time processed: 0:17:20
# | thread_5:	time processed: 0:17:00
# | thread_0:	time processed: 0:14:50
# | thread_4:	time processed: 0:16:50
# | thread_2:	time processed: 0:15:10
# | thread_6:	time processed: 0:15:50
# | thread_1:	time processed: 0:15:00
# | thread_3:	time processed: 0:16:40
# | thread_4:	time processed: 0:18:10
# | thread_7:	time processed: 0:18:40
# | thread_0:	time processed: 0:16:10
# | thread_1:	time processed: 0:16:20
# | thread_2:	time processed: 0:16:30
# | thread_6:	time processed: 0:17:10
# | thread_5:	time processed: 0:18:20
# | thread_3:	time processed: 0:18:00
# | thread_4:	time processed: 0:19:30
# | thread_6:	time processed: 0:18:30
# | thread_2:	time processed: 0:17:50
# | thread_5:	time processed: 0:19:40| thread_7:	time processed: 0:20:00
#
# | thread_1:	time processed: 0:17:40
# | thread_0:	time processed: 0:17:30
# | thread_3:	time processed: 0:19:20
# | thread_4:	time processed: 0:20:50
# | thread_6:	time processed: 0:19:50
# | thread_1:	time processed: 0:19:00
# | thread_5:	time processed: 0:21:00
# | thread_7:	time processed: 0:21:20
# | thread_0:	time processed: 0:18:50
# | thread_2:	time processed: 0:19:10
# | thread_3:	time processed: 0:20:40
# | thread_4:	time processed: 0:22:10
# | thread_3:	time processed: 0:22:00
# | thread_2:	time processed: 0:20:30
# | thread_1:	time processed: 0:20:20
# | thread_6:	time processed: 0:21:10
# | thread_5:	time processed: 0:22:20
# | thread_0:	time processed: 0:20:10| thread_7:	time processed: 0:22:40
#
# | thread_3:	time processed: 0:23:20| thread_1:	time processed: 0:21:40
#
# | thread_2:	time processed: 0:21:50
# | thread_7:	time processed: 0:24:00
# | thread_6:	time processed: 0:22:30
# | thread_4:	time processed: 0:23:30
# | thread_0:	time processed: 0:21:30
# | thread_5:	time processed: 0:23:40
# | thread_1:	time processed: 0:23:00
# | thread_7:	time processed: 0:25:20
# | thread_0:	time processed: 0:22:50
# | thread_2:	time processed: 0:23:10
# | thread_6:	time processed: 0:23:50
# | thread_3:	time processed: 0:24:40
# | thread_4:	time processed: 0:24:50
# | thread_5:	time processed: 0:25:00
# | thread_1:	time processed: 0:24:20
# | thread_6:	time processed: 0:25:10
# | thread_7:	time processed: 0:26:40
# | thread_0:	time processed: 0:24:10
# | thread_4:	time processed: 0:26:10
# | thread_5:	time processed: 0:26:20| thread_2:	time processed: 0:24:30
#
# | thread_3:	time processed: 0:26:00
# | thread_1:	time processed: 0:25:40
# | thread_0:	time processed: 0:25:30
# | thread_4:	time processed: 0:27:30
# | thread_7:	time processed: 0:28:00
# | thread_2:	time processed: 0:25:50
# | thread_5:	time processed: 0:27:40
# | thread_6:	time processed: 0:26:30| thread_3:	time processed: 0:27:20
#
# | thread_1:	time processed: 0:27:00
# | thread_4:	time processed: 0:28:50
# | thread_3:	time processed: 0:28:40
# | thread_7:	time processed: 0:29:20
# | thread_5:	time processed: 0:29:00
# | thread_0:	time processed: 0:26:50
# | thread_6:	time processed: 0:27:50
# | thread_2:	time processed: 0:27:10
# | thread_1:	time processed: 0:28:20
# | thread_4:	time processed: 0:30:10
# | thread_3:	time processed: 0:30:00
# | thread_2:	time processed: 0:28:30
# | thread_7:	time processed: 0:30:40
# | thread_5:	time processed: 0:30:20
# | thread_0:	time processed: 0:28:10
# | thread_6:	time processed: 0:29:10
# | thread_1:	time processed: 0:29:40
# | thread_4:	time processed: 0:31:30
# | thread_3:	time processed: 0:31:20
# | thread_7:	time processed: 0:32:00
# | thread_6:	time processed: 0:30:30
# | thread_5:	time processed: 0:31:40
# | thread_0:	time processed: 0:29:30
# | thread_2:	time processed: 0:29:50
# | thread_1:	time processed: 0:31:00
# | thread_4:	time processed: 0:32:50
# | thread_3:	time processed: 0:32:40
# | thread_7:	time processed: 0:33:20
# | thread_6:	time processed: 0:31:50
# | thread_1:	time processed: 0:32:20
# | thread_5:	time processed: 0:33:00
# | thread_2:	time processed: 0:31:10
# | thread_0:	time processed: 0:30:50
# | thread_4:	time processed: 0:34:10
# | thread_7:	time processed: 0:34:40
# | thread_6:	time processed: 0:33:10
# | thread_5:	time processed: 0:34:20
# | thread_3:	time processed: 0:34:00
# | thread_0:	time processed: 0:32:10
# | thread_2:	time processed: 0:32:30
# | thread_1:	time processed: 0:33:40
# | thread_4:	time processed: 0:35:30
# | thread_7:	time processed: 0:36:00
# | thread_5:	time processed: 0:35:40
# | thread_3:	time processed: 0:35:20
# | thread_0:	time processed: 0:33:30
# | thread_6:	time processed: 0:34:30
# | thread_1:	time processed: 0:35:00
# | thread_2:	time processed: 0:33:50
# | thread_4:	time processed: 0:36:50
# | thread_7:	time processed: 0:37:20
# | thread_6:	time processed: 0:35:50
# | thread_2:	time processed: 0:35:10
# | thread_1:	time processed: 0:36:20
# | thread_3:	time processed: 0:36:40
# | thread_0:	time processed: 0:34:50
# | thread_5:	time processed: 0:37:00
# | thread_4:	time processed: 0:38:10
# | thread_2:	time processed: 0:36:30
# | thread_7:	time processed: 0:38:40
# | thread_6:	time processed: 0:37:10
# | thread_5:	time processed: 0:38:20
# | thread_0:	time processed: 0:36:10
# | thread_1:	time processed: 0:37:40
# | thread_3:	time processed: 0:38:00
# | thread_4:	time processed: 0:39:30
# | thread_7:	time processed: 0:40:00
# | thread_3:	time processed: 0:39:20
# | thread_2:	time processed: 0:37:50
# | thread_0:	time processed: 0:37:30
# | thread_6:	time processed: 0:38:30
# | thread_5:	time processed: 0:39:40
# | thread_1:	time processed: 0:39:00
# | thread_4:	time processed: 0:40:50
# | thread_7:	time processed: 0:41:20
# | thread_3:	time processed: 0:40:40
# | thread_1:	time processed: 0:40:20
# | thread_6:	time processed: 0:39:50
# | thread_5:	time processed: 0:41:00
# | thread_2:	time processed: 0:39:10
# | thread_4:	time processed: 0:42:10
# | thread_0:	time processed: 0:38:50
# | thread_7:	time processed: 0:42:40
# | thread_0:	time processed: 0:40:10
# | thread_2:	time processed: 0:40:30
# | thread_5:	time processed: 0:42:20
# | thread_1:	time processed: 0:41:40
# | thread_3:	time processed: 0:42:00
# | thread_4:	time processed: 0:43:30
# | thread_6:	time processed: 0:41:10
# | thread_7:	time processed: 0:44:00
# | thread_5:	time processed: 0:43:40
# | thread_1:	time processed: 0:43:00
# | thread_4:	time processed: 0:44:50
# | thread_6:	time processed: 0:42:30
# | thread_0:	time processed: 0:41:30
# | thread_3:	time processed: 0:43:20
# | thread_2:	time processed: 0:41:50
# | thread_7:	time processed: 0:45:20
# | thread_5:	time processed: 0:45:00
# | thread_4:	time processed: 0:46:10
# | thread_2:	time processed: 0:43:10
# | thread_3:	time processed: 0:44:40
# | thread_1:	time processed: 0:44:20
# | thread_6:	time processed: 0:43:50| thread_0:	time processed: 0:42:50
#
# | thread_7:	time processed: 0:46:40
# | thread_2:	time processed: 0:44:30| thread_6:	time processed: 0:45:10
#
# | thread_3:	time processed: 0:46:00
# | thread_5:	time processed: 0:46:20
# | thread_1:	time processed: 0:45:40
# | thread_4:	time processed: 0:47:30
# | thread_0:	time processed: 0:44:10
# | thread_7:	time processed: 0:48:00
# | thread_4:	time processed: 0:48:50
# | thread_5:	time processed: 0:47:40
# | thread_1:	time processed: 0:47:00
# | thread_6:	time processed: 0:46:30
# | thread_2:	time processed: 0:45:50
# | thread_0:	time processed: 0:45:30
# | thread_3:	time processed: 0:47:20
# | thread_7:	time processed: 0:49:20
# | thread_6:	time processed: 0:47:50
# | thread_0:	time processed: 0:46:50
# | thread_1:	time processed: 0:48:20
# | thread_2:	time processed: 0:47:10
# | thread_3:	time processed: 0:48:40
# | thread_7:	time processed: 0:50:40
# | thread_4:	time processed: 0:50:10
# | thread_5:	time processed: 0:49:00
# | thread_6:	time processed: 0:49:10
# | thread_1:	time processed: 0:49:40
# | thread_5:	time processed: 0:50:20
# | thread_3:	time processed: 0:50:00
# | thread_7:	time processed: 0:52:00
# | thread_4:	time processed: 0:51:30| thread_2:	time processed: 0:48:30
#
# | thread_0:	time processed: 0:48:10
# | thread_6:	time processed: 0:50:30
# | thread_5:	time processed: 0:51:40
# | thread_1:	time processed: 0:51:00
# | thread_2:	time processed: 0:49:50
# | thread_0:	time processed: 0:49:30
# | thread_4:	time processed: 0:52:50
# | thread_7:	time processed: 0:53:20
# | thread_3:	time processed: 0:51:20
# | thread_6:	time processed: 0:51:50
# | thread_2:	time processed: 0:51:10
# | thread_4:	time processed: 0:54:10
# | thread_0:	time processed: 0:50:50
# | thread_1:	time processed: 0:52:20
# | thread_3:	time processed: 0:52:40
# | thread_5:	time processed: 0:53:00
# | thread_7:	time processed: 0:54:40
# | thread_6:	time processed: 0:53:10
# | thread_2:	time processed: 0:52:30
# | thread_0:	time processed: 0:52:10
# | thread_5:	time processed: 0:54:20
# | thread_1:	time processed: 0:53:40
# | thread_4:	time processed: 0:55:30
# | thread_7:	time processed: 0:56:00
# | thread_3:	time processed: 0:54:00
# | thread_6:	time processed: 0:54:30
# | thread_2:	time processed: 0:53:50
# | thread_1:	time processed: 0:55:00
# | thread_0:	time processed: 0:53:30
# | thread_4:	time processed: 0:56:50
# | thread_3:	time processed: 0:55:20
# | thread_7:	time processed: 0:57:20
# | thread_5:	time processed: 0:55:40
# | thread_6:	time processed: 0:55:50
# | thread_2:	time processed: 0:55:10
# | thread_5:	time processed: 0:57:00
# | thread_1:	time processed: 0:56:20
# | thread_4:	time processed: 0:58:10
# | thread_6:	time processed: 0:57:10
# | thread_7:	time processed: 0:58:40
# | thread_0:	time processed: 0:54:50
# | thread_3:	time processed: 0:56:40
# | thread_2:	time processed: 0:56:30
# | thread_5:	time processed: 0:58:20| thread_3:	time processed: 0:58:00
#
# | thread_0:	time processed: 0:56:10
# | thread_6:	time processed: 0:58:30
# | thread_7:	time processed: 1:00:00
# | thread_1:	time processed: 0:57:40
# | thread_4:	time processed: 0:59:30
# | thread_2:	time processed: 0:57:50
# | thread_5:	time processed: 0:59:40
# | thread_3:	time processed: 0:59:20
# | thread_4:	time processed: 1:00:50
# | thread_6:	time processed: 0:59:50
# | thread_0:	time processed: 0:57:30
# | thread_7:	time processed: 1:01:20
# | thread_1:	time processed: 0:59:00
# | thread_2:	time processed: 0:59:10
# | thread_4:	time processed: 1:02:10
# | thread_0:	time processed: 0:58:50
# | thread_6:	time processed: 1:01:10
# | thread_7:	time processed: 1:02:40
# | thread_3:	time processed: 1:00:40
# | thread_5:	time processed: 1:01:00
# | thread_1:	time processed: 1:00:20
# | thread_2:	time processed: 1:00:30
# | thread_6:	time processed: 1:02:30
# | thread_4:	time processed: 1:03:30
# | thread_3:	time processed: 1:02:00
# | thread_7:	time processed: 1:04:00
# | thread_1:	time processed: 1:01:40
# | thread_0:	time processed: 1:00:10
# | thread_5:	time processed: 1:02:20
# | thread_2:	time processed: 1:01:50
# | thread_4:	time processed: 1:04:50
# | thread_5:	time processed: 1:03:40
# | thread_2:	time processed: 1:03:10
# | thread_0:	time processed: 1:01:30
# | thread_3:	time processed: 1:03:20
# | thread_6:	time processed: 1:03:50
# | thread_1:	time processed: 1:03:00
# | thread_7:	time processed: 1:05:20
# | thread_4:	time processed: 1:06:10
# | thread_1:	time processed: 1:04:20
# | thread_7:	time processed: 1:06:40
# | thread_3:	time processed: 1:04:40
# | thread_2:	time processed: 1:04:30
# | thread_0:	time processed: 1:02:50
# | thread_5:	time processed: 1:05:00
# | thread_6:	time processed: 1:05:10
# | thread_4:	time processed: 1:07:30
# | thread_5:	time processed: 1:06:20
# | thread_2:	time processed: 1:05:50
# | thread_7:	time processed: 1:08:00
# | thread_3:	time processed: 1:06:00
# | thread_1:	time processed: 1:05:40
# | thread_0:	time processed: 1:04:10
# | thread_6:	time processed: 1:06:30
# | thread_4:	time processed: 1:08:50
# | thread_7:	time processed: 1:09:20
# | thread_5:	time processed: 1:07:40
# | thread_0:	time processed: 1:05:30
# | thread_3:	time processed: 1:07:20
# | thread_6:	time processed: 1:07:50
# | thread_2:	time processed: 1:07:10
# | thread_1:	time processed: 1:07:00
# | thread_4:	time processed: 1:10:10
# | thread_7:	time processed: 1:10:40
# | thread_0:	time processed: 1:06:50
# | thread_3:	time processed: 1:08:40| thread_1:	time processed: 1:08:20
#
# | thread_6:	time processed: 1:09:10
# | thread_5:	time processed: 1:09:00| thread_2:	time processed: 1:08:30
#
# | thread_4:	time processed: 1:11:30
# | thread_7:	time processed: 1:12:00
# | thread_2:	time processed: 1:09:50
# | thread_0:	time processed: 1:08:10
# | thread_6:	time processed: 1:10:30
# | thread_1:	time processed: 1:09:40
# | thread_3:	time processed: 1:10:00| thread_5:	time processed: 1:10:20
#
# | thread_4:	time processed: 1:12:50
# | thread_7:	time processed: 1:13:20
# | thread_4:	time processed: 1:14:10
# | thread_6:	time processed: 1:11:50
# | thread_2:	time processed: 1:11:10
# | thread_0:	time processed: 1:09:30
# | thread_5:	time processed: 1:11:40
# | thread_3:	time processed: 1:11:20
# | thread_1:	time processed: 1:11:00
# | thread_7:	time processed: 1:14:40
# | thread_5:	time processed: 1:13:00
# | thread_3:	time processed: 1:12:40
# | thread_2:	time processed: 1:12:30
# | thread_0:	time processed: 1:10:50
# | thread_4:	time processed: 1:15:30
# | thread_6:	time processed: 1:13:10
# | thread_1:	time processed: 1:12:20
# | thread_7:	time processed: 1:16:00
# | thread_5:	time processed: 1:14:20
# | thread_6:	time processed: 1:14:30
# | thread_3:	time processed: 1:14:00
# | thread_4:	time processed: 1:16:50
# | thread_2:	time processed: 1:13:50
# | thread_0:	time processed: 1:12:10
# | thread_1:	time processed: 1:13:40
# | thread_7:	time processed: 1:17:20
# | thread_6:	time processed: 1:15:50
# | thread_4:	time processed: 1:18:10
# | thread_0:	time processed: 1:13:30
# | thread_2:	time processed: 1:15:10
# | thread_3:	time processed: 1:15:20
# | thread_5:	time processed: 1:15:40
# | thread_1:	time processed: 1:15:00
# | thread_7:	time processed: 1:18:40
# | thread_3:	time processed: 1:16:40
# | thread_6:	time processed: 1:17:10
# | thread_5:	time processed: 1:17:00
# | thread_1:	time processed: 1:16:20
# | thread_4:	time processed: 1:19:30
# | thread_0:	time processed: 1:14:50
# | thread_2:	time processed: 1:16:30
# | thread_7:	time processed: 1:20:00
# | thread_1:	time processed: 1:17:40
# | thread_6:	time processed: 1:18:30
# | thread_4:	time processed: 1:20:50
# | thread_5:	time processed: 1:18:20| thread_0:	time processed: 1:16:10
#
# | thread_7:	time processed: 1:21:20| thread_2:	time processed: 1:17:50
#
# | thread_3:	time processed: 1:18:00
# | thread_1:	time processed: 1:19:00
# | thread_6:	time processed: 1:19:50
# | thread_0:	time processed: 1:17:30
# | thread_5:	time processed: 1:19:40
# | thread_4:	time processed: 1:22:10
# | thread_7:	time processed: 1:22:40
# | thread_2:	time processed: 1:19:10
# | thread_3:	time processed: 1:19:20
# | thread_1:	time processed: 1:20:20
# | thread_0:	time processed: 1:18:50
# | thread_6:	time processed: 1:21:10
# | thread_2:	time processed: 1:20:30
# | thread_4:	time processed: 1:23:30
# | thread_5:	time processed: 1:21:00
# | thread_3:	time processed: 1:20:40
# | thread_7:	time processed: 1:24:00
# | thread_1:	time processed: 1:21:40
# | thread_7:	time processed: 1:25:20
# | thread_6:	time processed: 1:22:30
# | thread_5:	time processed: 1:22:20
# | thread_2:	time processed: 1:21:50
# | thread_3:	time processed: 1:22:00
# | thread_0:	time processed: 1:20:10
# | thread_4:	time processed: 1:24:50
# | thread_1:	time processed: 1:23:00
# | thread_5:	time processed: 1:23:40
# | thread_3:	time processed: 1:23:20
# | thread_2:	time processed: 1:23:10
# | thread_4:	time processed: 1:26:10
# | thread_7:	time processed: 1:26:40
# | thread_6:	time processed: 1:23:50
# | thread_0:	time processed: 1:21:30
# | thread_1:	time processed: 1:24:20
# | thread_5:	time processed: 1:25:00
# | thread_3:	time processed: 1:24:40
# | thread_0:	time processed: 1:22:50
# | thread_2:	time processed: 1:24:30
# | thread_7:	time processed: 1:28:00
# | thread_4:	time processed: 1:27:30
# | thread_6:	time processed: 1:25:10
# | thread_1:	time processed: 1:25:40
# | thread_5:	time processed: 1:26:20
# | thread_2:	time processed: 1:25:50
# | thread_7:	time processed: 1:29:20
# | thread_0:	time processed: 1:24:10
# | thread_6:	time processed: 1:26:30
# | thread_3:	time processed: 1:26:00
# | thread_4:	time processed: 1:28:50
# | thread_1:	time processed: 1:27:00
# | thread_2:	time processed: 1:27:10
# | thread_7:	time processed: 1:30:40
# | thread_0:	time processed: 1:25:30
# | thread_4:	time processed: 1:30:10
# | thread_5:	time processed: 1:27:40
# | thread_3:	time processed: 1:27:20
# | thread_1:	time processed: 1:28:20
# | thread_6:	time processed: 1:27:50
# | thread_2:	time processed: 1:28:30
# | thread_7:	time processed: 1:32:00
# | thread_3:	time processed: 1:28:40
# | thread_4:	time processed: 1:31:30
# | thread_0:	time processed: 1:26:50
# | thread_1:	time processed: 1:29:40
# | thread_5:	time processed: 1:29:00
# | thread_6:	time processed: 1:29:10
# | thread_2:	time processed: 1:29:50
# | thread_7:	time processed: 1:33:20
# | thread_0:	time processed: 1:28:10
# | thread_5:	time processed: 1:30:20
# | thread_6:	time processed: 1:30:30
# | thread_3:	time processed: 1:30:00
# | thread_1:	time processed: 1:31:00
# | thread_4:	time processed: 1:32:50
# | thread_2:	time processed: 1:31:10
# | thread_7:	time processed: 1:34:40
# | thread_5:	time processed: 1:31:40
# | thread_0:	time processed: 1:29:30
# | thread_3:	time processed: 1:31:20
# | thread_6:	time processed: 1:31:50
# | thread_1:	time processed: 1:32:20
# | thread_4:	time processed: 1:34:10
# | thread_2:	time processed: 1:32:30
# | thread_5:	time processed: 1:33:00
# | thread_7:	time processed: 1:36:00
# | thread_0:	time processed: 1:30:50
# | thread_6:	time processed: 1:33:10
# | thread_4:	time processed: 1:35:30
# | thread_3:	time processed: 1:32:40
# | thread_1:	time processed: 1:33:40
# | thread_2:	time processed: 1:33:50
# | thread_7:	time processed: 1:37:20
# | thread_5:	time processed: 1:34:20
# | thread_0:	time processed: 1:32:10
# | thread_4:	time processed: 1:36:50
# | thread_3:	time processed: 1:34:00
# | thread_1:	time processed: 1:35:00
# | thread_6:	time processed: 1:34:30
# | thread_2:	time processed: 1:35:10
# | thread_7:	time processed: 1:38:40
# | thread_5:	time processed: 1:35:40
# | thread_4:	time processed: 1:38:10
# | thread_6:	time processed: 1:35:50
# | thread_0:	time processed: 1:33:30
# | thread_1:	time processed: 1:36:20
# | thread_3:	time processed: 1:35:20
# | thread_2:	time processed: 1:36:30
# | thread_7:	time processed: 1:40:00
# | thread_5:	time processed: 1:37:00
# | thread_6:	time processed: 1:37:10
# | thread_4:	time processed: 1:39:30
# | thread_3:	time processed: 1:36:40
# | thread_0:	time processed: 1:34:50
# | thread_1:	time processed: 1:37:40
# | thread_2:	time processed: 1:37:50
# | thread_7:	time processed: 1:41:20
# | thread_5:	time processed: 1:38:20
# | thread_1:	time processed: 1:39:00
# | thread_3:	time processed: 1:38:00
# | thread_6:	time processed: 1:38:30
# | thread_2:	time processed: 1:39:10
# | thread_0:	time processed: 1:36:10
# | thread_4:	time processed: 1:40:50
# | thread_7:	time processed: 1:42:40
# | thread_5:	time processed: 1:39:40
# | thread_1:	time processed: 1:40:20
# | thread_2:	time processed: 1:40:30
# | thread_6:	time processed: 1:39:50
# | thread_0:	time processed: 1:37:30
# | thread_3:	time processed: 1:39:20
# | thread_4:	time processed: 1:42:10
# | thread_7:	time processed: 1:44:00
# | thread_5:	time processed: 1:41:00
# | thread_1:	time processed: 1:41:40
# | thread_6:	time processed: 1:41:10
# | thread_0:	time processed: 1:38:50
# | thread_4:	time processed: 1:43:30
# | thread_2:	time processed: 1:41:50
# | thread_3:	time processed: 1:40:40
# | thread_7:	time processed: 1:45:20
# | thread_5:	time processed: 1:42:20
# | thread_1:	time processed: 1:43:00
# | thread_6:	time processed: 1:42:30
# | thread_4:	time processed: 1:44:50
# | thread_0:	time processed: 1:40:10
# | thread_3:	time processed: 1:42:00
# | thread_2:	time processed: 1:43:10
# | thread_5:	time processed: 1:43:40
# | thread_7:	time processed: 1:46:40
# | thread_1:	time processed: 1:44:20
# | thread_4:	time processed: 1:46:10
# | thread_2:	time processed: 1:44:30
# | thread_6:	time processed: 1:43:50
# | thread_7:	time processed: 1:48:00
# | thread_5:	time processed: 1:45:00
# | thread_0:	time processed: 1:41:30
# | thread_3:	time processed: 1:43:20
# | thread_1:	time processed: 1:45:40
# | thread_4:	time processed: 1:47:30
# | thread_2:	time processed: 1:45:50
# | thread_6:	time processed: 1:45:10
# | thread_7:	time processed: 1:49:20
# | thread_3:	time processed: 1:44:40
# | thread_0:	time processed: 1:42:50
# | thread_5:	time processed: 1:46:20
# | thread_1:	time processed: 1:47:00
# | thread_4:	time processed: 1:48:50
# | thread_2:	time processed: 1:47:10
# | thread_6:	time processed: 1:46:30
# | thread_0:	time processed: 1:44:10
# | thread_3:	time processed: 1:46:00
# | thread_5:	time processed: 1:47:40
# | thread_1:	time processed: 1:48:20
# | thread_7:	time processed: 1:50:40
# | thread_4:	time processed: 1:50:10
# | thread_2:	time processed: 1:48:30
# | thread_3:	time processed: 1:47:20
# | thread_0:	time processed: 1:45:30
# | thread_7:	time processed: 1:52:00
# | thread_5:	time processed: 1:49:00
# | thread_1:	time processed: 1:49:40
# | thread_6:	time processed: 1:47:50
# | thread_4:	time processed: 1:51:30
# | thread_2:	time processed: 1:49:50
# | thread_7:	time processed: 1:53:20
# | thread_1:	time processed: 1:51:00
# | thread_3:	time processed: 1:48:40
# | thread_0:	time processed: 1:46:50
# | thread_6:	time processed: 1:49:10
# | thread_5:	time processed: 1:50:20
# | thread_4:	time processed: 1:52:50
# | thread_2:	time processed: 1:51:10
# | thread_1:	time processed: 1:52:20
# | thread_7:	time processed: 1:54:40
# | thread_6:	time processed: 1:50:30
# | thread_3:	time processed: 1:50:00
# | thread_0:	time processed: 1:48:10
# | thread_5:	time processed: 1:51:40
# | thread_4:	time processed: 1:54:10
# | thread_2:	time processed: 1:52:30
# | thread_7:	time processed: 1:56:00
# | thread_1:	time processed: 1:53:40
# | thread_6:	time processed: 1:51:50
# | thread_3:	time processed: 1:51:20
# | thread_5:	time processed: 1:53:00
# | thread_0:	time processed: 1:49:30
# | thread_4:	time processed: 1:55:30
# | thread_2:	time processed: 1:53:50
# | thread_7:	time processed: 1:57:20
# | thread_1:	time processed: 1:55:00
# | thread_6:	time processed: 1:53:10
# | thread_5:	time processed: 1:54:20
# | thread_0:	time processed: 1:50:50
# | thread_3:	time processed: 1:52:40
# | thread_4:	time processed: 1:56:50
# | thread_2:	time processed: 1:55:10
# | thread_7:	time processed: 1:58:40
# | thread_1:	time processed: 1:56:20
# | thread_6:	time processed: 1:54:30
# | thread_3:	time processed: 1:54:00
# | thread_0:	time processed: 1:52:10
# | thread_5:	time processed: 1:55:40
# | thread_2:	time processed: 1:56:30
# | thread_4:	time processed: 1:58:10
# | thread_7:	time processed: 2:00:00
# | thread_1:	time processed: 1:57:40
# | thread_6:	time processed: 1:55:50
# | thread_5:	time processed: 1:57:00
# | thread_3:	time processed: 1:55:20
# | thread_0:	time processed: 1:53:30
# | thread_2:	time processed: 1:57:50
# | thread_4:	time processed: 1:59:30
# | thread_7:	time processed: 2:01:20
# | thread_1:	time processed: 1:59:00
# | thread_6:	time processed: 1:57:10
# | thread_5:	time processed: 1:58:20
# | thread_4:	time processed: 2:00:50
# | thread_3:	time processed: 1:56:40
# | thread_0:	time processed: 1:54:50
# | thread_2:	time processed: 1:59:10
# | thread_7:	time processed: 2:02:40
# | thread_1:	time processed: 2:00:20
# | thread_6:	time processed: 1:58:30
# | thread_5:	time processed: 1:59:40
# | thread_0:	time processed: 1:56:10
# | thread_4:	time processed: 2:02:10
# | thread_3:	time processed: 1:58:00
# | thread_2:	time processed: 2:00:30
# | thread_7:	time processed: 2:04:00
# | thread_1:	time processed: 2:01:40
# | thread_6:	time processed: 1:59:50
# | thread_5:	time processed: 2:01:00
# | thread_0:	time processed: 1:57:30
# | thread_4:	time processed: 2:03:30
# | thread_3:	time processed: 1:59:20
# | thread_2:	time processed: 2:01:50
# | thread_7:	time processed: 2:05:20
# | thread_1:	time processed: 2:03:00
# | thread_6:	time processed: 2:01:10
# | thread_5:	time processed: 2:02:20
# | thread_0:	time processed: 1:58:50
# | thread_2:	time processed: 2:03:10
# | thread_4:	time processed: 2:04:50
# | thread_3:	time processed: 2:00:40
# | thread_7:	time processed: 2:06:40
# | thread_1:	time processed: 2:04:20
# | thread_6:	time processed: 2:02:30
# | thread_5:	time processed: 2:03:40
# | thread_0:	time processed: 2:00:10
# | thread_4:	time processed: 2:06:10
# | thread_2:	time processed: 2:04:30
# | thread_3:	time processed: 2:02:00
# | thread_7:	time processed: 2:08:00
# | thread_1:	time processed: 2:05:40
# | thread_6:	time processed: 2:03:50
# | thread_5:	time processed: 2:05:00
# | thread_0:	time processed: 2:01:30
# | thread_4:	time processed: 2:07:30
# | thread_2:	time processed: 2:05:50
# | thread_7:	time processed: 2:09:20
# | thread_3:	time processed: 2:03:20
# | thread_1:	time processed: 2:07:00
# | thread_6:	time processed: 2:05:10
# | thread_5:	time processed: 2:06:20
# | thread_0:	time processed: 2:02:50
# | thread_2:	time processed: 2:07:10
# | thread_4:	time processed: 2:08:50
# | thread_7:	time processed: 2:10:40
# | thread_3:	time processed: 2:04:40
# | thread_6:	time processed: 2:06:30
# | thread_1:	time processed: 2:08:20
# | thread_5:	time processed: 2:07:40
# | thread_0:	time processed: 2:04:10
# | thread_2:	time processed: 2:08:30
# | thread_4:	time processed: 2:10:10
# | thread_7:	time processed: 2:12:00
# | thread_3:	time processed: 2:06:00
# | thread_6:	time processed: 2:07:50
# | thread_1:	time processed: 2:09:40
# | thread_5:	time processed: 2:09:00
# | thread_0:	time processed: 2:05:30
# | thread_2:	time processed: 2:09:50
# | thread_4:	time processed: 2:11:30
# | thread_7:	time processed: 2:13:20
# | thread_6:	time processed: 2:09:10
# | thread_3:	time processed: 2:07:20
# | thread_1:	time processed: 2:11:00
# | thread_5:	time processed: 2:10:20
# | thread_0:	time processed: 2:06:50
# | thread_2:	time processed: 2:11:10
# | thread_4:	time processed: 2:12:50
# | thread_7:	time processed: 2:14:40
# | thread_6:	time processed: 2:10:30
# | thread_5:	time processed: 2:11:40
# | thread_3:	time processed: 2:08:40
# | thread_1:	time processed: 2:12:20
# | thread_0:	time processed: 2:08:10
# | thread_2:	time processed: 2:12:30
# | thread_4:	time processed: 2:14:10
# | thread_7:	time processed: 2:16:00
# | thread_6:	time processed: 2:11:50
# | thread_5:	time processed: 2:13:00
# | thread_3:	time processed: 2:10:00
# | thread_1:	time processed: 2:13:40
# | thread_0:	time processed: 2:09:30
# | thread_2:	time processed: 2:13:50
# | thread_4:	time processed: 2:15:30
# | thread_7:	time processed: 2:17:20
# | thread_5:	time processed: 2:14:20
# | thread_6:	time processed: 2:13:10
# | thread_1:	time processed: 2:15:00
# | thread_3:	time processed: 2:11:20
# | thread_0:	time processed: 2:10:50
# | thread_2:	time processed: 2:15:10
# | thread_4:	time processed: 2:16:50
# | thread_7:	time processed: 2:18:40
# | thread_5:	time processed: 2:15:40
# | thread_6:	time processed: 2:14:30
# | thread_1:	time processed: 2:16:20
# | thread_3:	time processed: 2:12:40
# | thread_0:	time processed: 2:12:10
# | thread_2:	time processed: 2:16:30
# | thread_4:	time processed: 2:18:10
# | thread_7:	time processed: 2:20:00
# | thread_5:	time processed: 2:17:00
# | thread_6:	time processed: 2:15:50
# | thread_3:	time processed: 2:14:00
# | thread_1:	time processed: 2:17:40
# | thread_0:	time processed: 2:13:30
# | thread_2:	time processed: 2:17:50
# | thread_4:	time processed: 2:19:30
# | thread_7:	time processed: 2:21:20
# | thread_5:	time processed: 2:18:20
# | thread_6:	time processed: 2:17:10
# | thread_3:	time processed: 2:15:20
# | thread_1:	time processed: 2:19:00
# | thread_0:	time processed: 2:14:50
# | thread_2:	time processed: 2:19:10
# | thread_4:	time processed: 2:20:50
# | thread_7:	time processed: 2:22:40
# | thread_5:	time processed: 2:19:40
# | thread_6:	time processed: 2:18:30
# | thread_3:	time processed: 2:16:40
# | thread_1:	time processed: 2:20:20
# | thread_0:	time processed: 2:16:10
# | thread_2:	time processed: 2:20:30
# | thread_4:	time processed: 2:22:10
# | thread_7:	time processed: 2:24:00
# | thread_5:	time processed: 2:21:00
# | thread_6:	time processed: 2:19:50
# | thread_1:	time processed: 2:21:40
# | thread_3:	time processed: 2:18:00
# | thread_0:	time processed: 2:17:30
# | thread_2:	time processed: 2:21:50
# | thread_4:	time processed: 2:23:30
# | thread_7:	time processed: 2:25:20
# | thread_5:	time processed: 2:22:20
# | thread_6:	time processed: 2:21:10
# | thread_3:	time processed: 2:19:20
# | thread_1:	time processed: 2:23:00
# | thread_0:	time processed: 2:18:50
# | thread_2:	time processed: 2:23:10
# | thread_4:	time processed: 2:24:50
# | thread_7:	time processed: 2:26:40
# | thread_5:	time processed: 2:23:40
# | thread_6:	time processed: 2:22:30
# | thread_1:	time processed: 2:24:20
# | thread_3:	time processed: 2:20:40
# | thread_0:	time processed: 2:20:10
# | thread_2:	time processed: 2:24:30
# | thread_4:	time processed: 2:26:10
# | thread_7:	time processed: 2:28:00
# | thread_5:	time processed: 2:25:00
# | thread_6:	time processed: 2:23:50
# | thread_1:	time processed: 2:25:40
# | thread_3:	time processed: 2:22:00
# | thread_0:	time processed: 2:21:30
# | thread_2:	time processed: 2:25:50
# | thread_4:	time processed: 2:27:30
# | thread_7:	time processed: 2:29:20
# | thread_5:	time processed: 2:26:20
# | thread_6:	time processed: 2:25:10
# | thread_1:	time processed: 2:27:00
# | thread_3:	time processed: 2:23:20
# | thread_0:	time processed: 2:22:50
# | thread_2:	time processed: 2:27:10
# | thread_4:	time processed: 2:28:50
# | thread_7:	time processed: 2:30:40
# | thread_5:	time processed: 2:27:40
# | thread_6:	time processed: 2:26:30
# | thread_1:	time processed: 2:28:20
# | thread_3:	time processed: 2:24:40
# | thread_0:	time processed: 2:24:10
# | thread_2:	time processed: 2:28:30
# | thread_4:	time processed: 2:30:10
# | thread_7:	time processed: 2:32:00
# | thread_5:	time processed: 2:29:00
# | thread_6:	time processed: 2:27:50
# thread_7 finished.
# | thread_1:	time processed: 2:29:40
# | thread_3:	time processed: 2:26:00
# | thread_2:	time processed: 2:29:50
# | thread_0:	time processed: 2:25:30
# | thread_4:	time processed: 2:31:30
# | thread_5:	time processed: 2:30:20
# | thread_6:	time processed: 2:29:10
# thread_4 finished.
# | thread_3:	time processed: 2:27:20
# | thread_1:	time processed: 2:31:00
# | thread_0:	time processed: 2:26:50
# | thread_2:	time processed: 2:31:10
# thread_1 finished.
# | thread_5:	time processed: 2:31:40
# | thread_6:	time processed: 2:30:30
# thread_2 finished.
# thread_5 finished.
# | thread_3:	time processed: 2:28:40
# | thread_0:	time processed: 2:28:10
# | thread_6:	time processed: 2:31:50
# thread_6 finished.
# | thread_3:	time processed: 2:30:00
# | thread_0:	time processed: 2:29:30
# | thread_3:	time processed: 2:31:20
# thread_3 finished.
# | thread_0:	time processed: 2:30:50
# thread_0 finished.
# Joining thread_0
# Joining thread_1
# Joining thread_2
# Joining thread_3
# Joining thread_4
# Joining thread_5
# Joining thread_6
# Joining thread_7
# 0
